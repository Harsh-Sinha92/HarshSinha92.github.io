# %%
import pandas as pd
import os as os
from openpyxl import load_workbook
from datetime import datetime,timedelta

# %%
print("Data received from Monica Grace.")
#Program to read values from one file and write in another file.
current_dir=os.getcwd
new_dir=r'C:\\Users\\user\\Desktop'
os.chdir(new_dir)
current_dir=os.getcwd()
print("Current Directory after directory change: ",current_dir)
Files_inside_dir=os.listdir()
print("Files inside Directory: ",Files_inside_dir)
# Get the current month and year
current_date = datetime.now()
# Calculate the previous month
prev_month_date = current_date.replace(day=1)- timedelta(days=1) 
prev_month = prev_month_date.strftime("%B") 
print("Previous Month: ",prev_month)
prev_month_short = prev_month_date.strftime("%b") 
current_year = current_date.strftime("%Y")
current_year_short = current_date.strftime("%y")
# Add one more year to the current date
next_year_date = current_date.replace(year=current_date.year + 1)
next_year = next_year_date.strftime("%y")
print("Next Year: ", next_year)
# Construct the Destination and source filename
file_s = f"BUMC_FY{next_year} Monthly Bed Report.xlsx" #Monica Grace
file_d = f"{prev_month_short} {current_year} Consolidated Stats.xlsx"
print("Constructed Source filename:", file_s)
print("Constructed Destination filename:", file_d)
# Check if the constructed filenames are in the directory
if file_s in Files_inside_dir:
    print("Source filename found in directory:", file_s)
else:
    print("Source filename not found in directory.")
if file_d in Files_inside_dir:
    print("Destination filename found in directory:", file_d)
else:
    print("Destination filename not found in directory.")
#Opening Source file from where value is to be taken
source_wb=load_workbook(file_s)
source_ws=source_ws = source_wb['Report'] 
#Opening Destination file where value is to be written
destination_wb=load_workbook(file_d)
destination_ws=destination_ws = destination_wb['Journal Load Template']
month_column = None
for col in range(9, 21):  # Assuming the months are in columns I to T
    if source_ws.cell(row=57, column=col).value == prev_month: 
        month_column = col
        break
# If month_column is found, fetch data from the corresponding rows
if month_column:
    source_rows_range = range(58, 63)  # Adjust range based on the month column
#Identifying the cells to the particular row where values from source file needs to be copied into.\n",
id_1=1000
id_2=91000
id_3=950640
id_4=950641
id_5=950642
id_6=950643
id_7=950645
#Initialising the destination rows.
des_row_1=des_row_2=des_row_3=des_row_4=des_row_5=None
#Targeting the specified row into which the writing of the values needs to be done
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
    if row[0].value == id_1 and row[1].value == id_2 and row[2].value == id_3:
        des_row_1 = row[0].row
    elif row[0].value == id_1 and row[1].value == id_2 and row[2].value == id_4:
        des_row_2 = row[0].row
    elif row[0].value == id_1 and row[1].value == id_2 and row[2].value == id_5:
        des_row_3 = row[0].row
    elif row[0].value == id_1 and row[1].value == id_2 and row[2].value == id_6:
        des_row_4 = row[0].row
    elif row[0].value == id_1 and row[1].value == id_2 and row[2].value == id_7:
        des_row_5 = row[0].row
destination_rows = [des_row_1, des_row_2, des_row_3, des_row_4, des_row_5]
    # Extract data from source file
source_data = [source_ws.cell(row=i, column=month_column).value for i in source_rows_range]
    # Extract data from destination file
destination_data = [destination_ws[f'F{i}'].value for i in destination_rows]
print("Source Data:", source_data)
print("Destination Data:", destination_data)
# Check if the data matches
if source_data == destination_data:
        print("Data matches for the current month for BUMC.")
else:
        print("There is some mismatch as rows might have been changed in Manual JE file or unable to be picked up from source file for BUMC.")
# Close both workbooks
source_wb.close()
destination_wb.close()
print("File has been validated for beds in BUMC(1000).")
# Out:
# Data received from Monica Grace.
# Current Directory after directory change:  C:\Users\user\Desktop
# Files inside Directory:  ['2024 MRVU August.xlsx', '950680_APR_05072024.xlsx', 'Aug 2024 Consolidated Stats.xlsx', 'August pat 2024 numbers.xlsx', 'BUMC_FY25 Monthly Bed Report.xlsx', 'CMI & CWAD Calculations April 2024.xlsx', 'CMICWADMOYTD.xlsx', 'desktop.ini', 'HealthCare Basics.txt', 'Laundry_MASTER_FY2025.xlsx', 'Manual JE Codes_Updated', 'Mapping Tabs for Lawson v5-16-24.xlsx', 'MIDAS CMI By Payor APR.xlsx', 'Month End Numbers August 24.xlsx', 'OUTREACH RVU FY25.xlsx', 'Scorecard FY24(5140.10590).xlsx', 'TouchStone_RVUs-Extract.xlsx', 'Transport Volumes Monthly FY2025.xlsx', 'tss3333ddsinq.xlsx']
# Previous Month:  August
# Next Year:  25
# Constructed Source filename: BUMC_FY25 Monthly Bed Report.xlsx
# Constructed Destination filename: Aug 2024 Consolidated Stats.xlsx
# Source filename found in directory: BUMC_FY25 Monthly Bed Report.xlsx
# Destination filename found in directory: Aug 2024 Consolidated Stats.xlsx
# Source Data: [888, 784, 52, 52, 914]
# Destination Data: [888, 784, 52, 52, 914]
# Data matches for the current month for BUMC.
# File has been validated for beds in BUMC(1000).
