# %%
#Program to read values from one file and write in another file.
file_s='Desktop\TouchStone_RVUs-Extract.xlsx'
file_d='Desktop\Apr 2024 Consolidated Stats.xlsx'
#Opening Source file from where value is to be taken
source_wb=load_workbook(file_s)
source_ws=source_wb.active
#Opening Destination file where value is to be written
destination_wb=load_workbook(file_d)
destination_ws=destination_wb.active
#Identifying the cells to the particular row where values from source file needs to be copied into.\n",
id_1=5500
id_2=34610
id_3=5500
id_4=34914
id_5=5510
id_6=30034
id_7=5512
id_8=36164
id_9=5514
id_10=37134
id_11=5516
id_12=38282
id_13=5500
id_14=34814
id_15=5512
id_16=36186
#Initialising the destination rows.
des_row_1=None
des_row_2=None
des_row_3=None
des_row_4=None
des_row_5=None
des_row_6=None
des_row_7=None
des_row_8=None
#Targeting the specified row into which the writing of the values needs to be done
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_1 and row[1].value == id_2:
            des_row_1 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_3 and row[1].value == id_4:
            des_row_2 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_5 and row[1].value == id_6:
            des_row_3 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_7 and row[1].value == id_8:
            des_row_4 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_9 and row[1].value == id_10:
            des_row_5 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_11 and row[1].value == id_12:
            des_row_6 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_13 and row[1].value == id_14:
            des_row_7 = row[0].row
            break
for row in destination_ws.iter_rows(min_row=2, max_row=destination_ws.max_row, min_col=1, max_col=3):
       if row[0].value == id_15 and row[1].value == id_16:
            des_row_8 = row[0].row
            break
#For matching rows Values from source file are copied
if des_row_1:
        source_value_1 = source_ws['K96'].value 
if des_row_2:
        source_value_2 = source_ws['K97'].value 
if des_row_3:
        source_value_3 = source_ws['K98'].value 
if des_row_4:
        source_value_4 = source_ws['K99'].value 
if des_row_5:
        source_value_5 = source_ws['K100'].value 
if des_row_6:
        source_value_6 = source_ws['K101'].value 
if des_row_7:
        source_value_7 = source_ws['K102'].value 
if des_row_8:
        source_value_8 = source_ws['K103'].value 
#Writing values to destination cell
destination_ws.cell(row=des_row_1, column=6).value = source_value_1
destination_ws.cell(row=des_row_2, column=6).value = source_value_2
destination_ws.cell(row=des_row_3, column=6).value = source_value_3
destination_ws.cell(row=des_row_4, column=6).value = source_value_4
destination_ws.cell(row=des_row_5, column=6).value = source_value_5
destination_ws.cell(row=des_row_6, column=6).value = source_value_6
destination_ws.cell(row=des_row_7, column=6).value = source_value_7
destination_ws.cell(row=des_row_8, column=6).value = source_value_8

#Saving the destination file
destination_wb.save(file_d)
#Close both workbooks
source_wb.close()
destination_wb.close()
print("File have been updated successfully.")
